# %% [markdown]
# # IMMOO ELIZA ML

# %% [markdown]
# ### import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.sparse import hstack
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### importing dataset

# %%
path = "../data/data_properties.csv"

df = pd.read_csv(path)
df.head()
# Out:
#          id    region       province district  locality  postalcode  \
# 0  10858284  Wallonie     Luxembourg    Arlon   Halanzy        6792
# 1  10930768  Flanders        Antwerp  Antwerp   Antwerp        2018
# 2  11137665  Flanders  East Flanders     Gent  Ertvelde        9940
# 3  10966577  Flanders        Antwerp  Antwerp  Kapellen        2950
# 4  11110694  Flanders        Antwerp  Antwerp    Deurne        2100
#
#     latitude  longitude  price_main       type  ...    condition facadeCount  \
# 0  49.582632   5.756293    220000.0      HOUSE  ...  TO_RENOVATE         3.0
# 1  51.194594   4.407379    589500.0  APARTMENT  ...         GOOD         4.0
# 2  51.179353   3.740274    825000.0      HOUSE  ...          NaN         4.0
# 3  51.345060   4.401032    575000.0      HOUSE  ...         GOOD         4.0
# 4  51.234994   4.470870    179000.0  APARTMENT  ...       AS_NEW         3.0
#
#    hasKitchenSetup isFurnished  fireplaceExists  hasSwimmingPool  \
# 0    SEMI_EQUIPPED         0.0                0              0.0
# 1        INSTALLED         NaN                0              NaN
# 2    SEMI_EQUIPPED         NaN                1              NaN
# 3              NaN         NaN                0              NaN
# 4    SEMI_EQUIPPED         NaN                1              NaN
#
#    terraceSurface       floodZone  gardenSurface isNewRealEstateProject
# 0            42.0             NaN           80.0                      0
# 1            28.0  NON_FLOOD_ZONE            NaN                      0
# 2             NaN  NON_FLOOD_ZONE         1635.0                      0
# 3             NaN  NON_FLOOD_ZONE            NaN                      0
# 4             3.0  NON_FLOOD_ZONE            NaN                      0
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Handeling outliers

# %%
Q1 = df['price_main'].quantile(0.25) #Calculate Q1
Q3 = df['price_main'].quantile(0.75) #Calculate Q3

IQR = Q3 - Q1 #Calculate IQ range

lower_bound = Q1 - 1.5 * IQR #Calculate the lower bound
upper_bound = Q3 + 1.5 * IQR #Calculate the upper bound

df = df[(df['price_main'] >= lower_bound) & (df['price_main'] <= upper_bound)] # Filter rows where 'price_main' < lb or > ub
df.shape
# Out:
# (54802, 29)

# %% [markdown]
# #### deleting columns where values don't have much impact on the price

# %%
columns_to_drop = ['cadastralIncome', 'id', 'primaryEnergyConsumption', 'isNewRealEstateProject', 'longitude', 'latitude', 'locality', 'postalcode']
df = df.drop(columns=columns_to_drop)

# %% [markdown]
# #### assuming isFurnished, hasSwimmingPool were not mentioned because it is not present

# %%
# Replace NaN values in 'isFurnished' and 'hasSwimmingPool' columns with 0
df['isFurnished'].fillna(0, inplace=True)
df['hasSwimmingPool'].fillna(0, inplace=True)
#df['floodZone'].fillna("NON_FLOOD_ZONE", inplace=True)
print(df.head(20))
# Out:
#       region         province    district  price_main       type  \
# 0   Wallonie       Luxembourg       Arlon    220000.0      HOUSE
# 1   Flanders          Antwerp     Antwerp    589500.0  APARTMENT
# 3   Flanders          Antwerp     Antwerp    575000.0      HOUSE
# 4   Flanders          Antwerp     Antwerp    179000.0  APARTMENT
# 5   Flanders    East Flanders        Gent    549000.0  APARTMENT
# 6   Flanders  Flemish Brabant      Leuven    439000.0      HOUSE
# 7   Wallonie            Namur      Dinant    130000.0  APARTMENT
# 8   Wallonie          Hainaut   Charleroi    105000.0  APARTMENT
# 10  Wallonie            Liège       Liège    169000.0      HOUSE
# 11  Flanders    East Flanders        Gent    465000.0  APARTMENT
# 12  Flanders    East Flanders  Oudenaarde    169000.0      HOUSE
# 13  Flanders  Flemish Brabant      Leuven    399000.0  APARTMENT
# 14  Flanders          Limburg    Tongeren    269938.0  APARTMENT
# 15  Wallonie  Walloon Brabant    Nivelles    390000.0      HOUSE
# 16  Flanders    East Flanders       Aalst    250000.0      HOUSE
# 17  Wallonie            Namur       Namur    495000.0      HOUSE
# 18  Wallonie  Walloon Brabant    Nivelles    229000.0  APARTMENT
# 19  Flanders          Antwerp     Antwerp    579000.0      HOUSE
# 20  Flanders          Antwerp    Mechelen    414000.0      HOUSE
# 21  Flanders          Antwerp    Mechelen    199000.0      HOUSE
#
#                subtype heatingType epcScores  bedrooms  surface  ...  \
# 0                HOUSE     FUELOIL         G       4.0    159.0  ...
# 1            APARTMENT         GAS         B       3.0    200.0  ...
# 3                VILLA         GAS         D       4.0    265.0  ...
# 4            APARTMENT         GAS         C       2.0     91.0  ...
# 5            APARTMENT         NaN         A       3.0    120.0  ...
# 6                HOUSE         GAS         C       5.0    202.0  ...
# 7            APARTMENT    ELECTRIC       NaN       3.0     70.0  ...
# 8            APARTMENT         NaN         C       1.0     73.0  ...
# 10               HOUSE         GAS         G       4.0    180.0  ...
# 11           APARTMENT     FUELOIL         B       2.0     88.0  ...
# 12               HOUSE    ELECTRIC       NaN       2.0      NaN  ...
# 13           APARTMENT         GAS         A       1.0    118.0  ...
# 14           APARTMENT         GAS         A       1.0    100.0  ...
# 15               HOUSE         GAS       NaN       3.0    165.0  ...
# 16  MIXED_USE_BUILDING         GAS         B       4.0    180.0  ...
# 17               HOUSE     FUELOIL         D       3.0    200.0  ...
# 18             TRIPLEX         GAS         B       3.0    141.0  ...
# 19               HOUSE         GAS         C       3.0    190.0  ...
# 20               HOUSE         NaN       NaN       4.0    166.0  ...
# 21               HOUSE      CARBON         F       2.0     75.0  ...
#
#     hasGasWaterElectricityConnection       condition facadeCount  \
# 0                                NaN     TO_RENOVATE         3.0
# 1                                NaN            GOOD         4.0
# 3                                1.0            GOOD         4.0
# 4                                NaN          AS_NEW         3.0
# 5                                NaN            GOOD         4.0
# 6                                1.0            GOOD         4.0
# 7                                NaN             NaN         2.0
# 8                                NaN            GOOD         2.0
# 10                               1.0            GOOD         2.0
# 11                               NaN             NaN         NaN
# 12                               1.0            GOOD         2.0
# 13                               NaN          AS_NEW         NaN
# 14                               NaN             NaN         4.0
# 15                               1.0     TO_RENOVATE         3.0
# 16                               1.0  JUST_RENOVATED         2.0
# 17                               NaN            GOOD         4.0
# 18                               NaN   TO_BE_DONE_UP         2.0
# 19                               1.0          AS_NEW         2.0
# 20                               NaN             NaN         NaN
# 21                               0.0            GOOD         NaN
#
#     hasKitchenSetup isFurnished  fireplaceExists  hasSwimmingPool  \
# 0     SEMI_EQUIPPED         0.0                0              0.0
# 1         INSTALLED         0.0                0              0.0
# 3               NaN         0.0                0              0.0
# 4     SEMI_EQUIPPED         0.0                1              0.0
# 5               NaN         0.0                0              0.0
# 6    HYPER_EQUIPPED         0.0                0              0.0
# 7         INSTALLED         1.0                1              0.0
# 8               NaN         0.0                0              0.0
# 10        INSTALLED         0.0                0              0.0
# 11              NaN         0.0                0              0.0
# 12    SEMI_EQUIPPED         0.0                0              0.0
# 13              NaN         0.0                0              0.0
# 14   HYPER_EQUIPPED         0.0                0              0.0
# 15    NOT_INSTALLED         0.0                1              0.0
# 16    SEMI_EQUIPPED         0.0                0              0.0
# 17   HYPER_EQUIPPED         0.0                0              0.0
# 18        INSTALLED         0.0                0              0.0
# 19        INSTALLED         0.0                0              0.0
# 20   HYPER_EQUIPPED         0.0                0              0.0
# 21    NOT_INSTALLED         0.0                0              0.0
#
#     terraceSurface              floodZone gardenSurface
# 0             42.0                    NaN          80.0
# 1             28.0         NON_FLOOD_ZONE           NaN
# 3              NaN         NON_FLOOD_ZONE           NaN
# 4              3.0         NON_FLOOD_ZONE           NaN
# 5              NaN         NON_FLOOD_ZONE          16.0
# 6              NaN         NON_FLOOD_ZONE           NaN
# 7             38.0                    NaN           NaN
# 8              NaN                    NaN           NaN
# 10            22.0                    NaN           NaN
# 11           100.0         NON_FLOOD_ZONE           NaN
# 12            12.0         NON_FLOOD_ZONE          90.0
# 13            11.0         NON_FLOOD_ZONE           NaN
# 14            38.0    POSSIBLE_FLOOD_ZONE         304.0
# 15             NaN                    NaN         250.0
# 16             NaN  RECOGNIZED_FLOOD_ZONE           NaN
# 17             NaN                    NaN           NaN
# 18             NaN                    NaN           NaN
# 19            12.0         NON_FLOOD_ZONE          82.0
# 20             NaN                    NaN           NaN
# 21             NaN         NON_FLOOD_ZONE           NaN
#
# [20 rows x 21 columns]
# C:\Users\arian\AppData\Local\Temp\ipykernel_9360\3929314369.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['isFurnished'].fillna(0, inplace=True)
# C:\Users\arian\AppData\Local\Temp\ipykernel_9360\3929314369.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['hasSwimmingPool'].fillna(0, inplace=True)

# %% [markdown]
# ### Handeling missing data (SimpleImputer)
# * delete everything without price_main + remove columns with 50%+ missing data
#
# * columns with missing values:
#     * heatingType
#     * epcScores
#     * primaryEnergyConsumption
#     * bedrooms
#     * surface
#     * surfaceGood
#     * condition
#     * facadeCount
#     * hasKitchenSetup
#     * hasSwimmingPool
#     * floodZone

# %%
missing_data_all = df.isna().sum()
percentage_missing_all = round(missing_data_all * 100 / len(df), 0)
print(f'For all proporties :\n {percentage_missing_all}')
# Out:
# For all proporties :
#  region                               0.0
# province                             0.0
# district                             0.0
# price_main                           0.0
# type                                 0.0
# subtype                              0.0
# heatingType                         34.0
# epcScores                           29.0
# bedrooms                             0.0
# surface                             13.0
# surfaceGood                         41.0
# hasGasWaterElectricityConnection    66.0
# condition                           30.0
# facadeCount                         30.0
# hasKitchenSetup                     44.0
# isFurnished                          0.0
# fireplaceExists                      0.0
# hasSwimmingPool                      0.0
# terraceSurface                      66.0
# floodZone                           44.0
# gardenSurface                       81.0
# dtype: float64

# %%
#drop columns with more than 50% missing values
def get_column_missing_values():
    columns_to_drop = []
    for column, missing_percentage in percentage_missing_all.items():
        if missing_percentage >= 50:
            columns_to_drop.append(column)
    return columns_to_drop
    
print(get_column_missing_values())
df.drop(columns=get_column_missing_values(), inplace=True)  # Modify DataFrame inplace
print(df.dtypes)
# Out:
# ['hasGasWaterElectricityConnection', 'terraceSurface', 'gardenSurface']
# region              object
# province            object
# district            object
# price_main         float64
# type                object
# subtype             object
# heatingType         object
# epcScores           object
# bedrooms           float64
# surface            float64
# surfaceGood        float64
# condition           object
# facadeCount        float64
# hasKitchenSetup     object
# isFurnished        float64
# fireplaceExists      int64
# hasSwimmingPool    float64
# floodZone           object
# dtype: object

# %%
#train all properties
X = df.drop(['price_main'], axis=1)
y = df.price_main

X_train, X_test, y_train, y_test = train_test_split( X,y, test_size=0.2, random_state=1)
print(type(X_train), type(X_test), type(y_train), type(y_test))
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.series.Series'> <class 'pandas.core.series.Series'>

# %%
def impute_missing_values(X_train, X_test):
    # Impute missing values for numerical features
    numerical_imputer = SimpleImputer(strategy='mean')
    numerical_features = X_train.select_dtypes(include=['int64', 'float64']).columns
    X_train[numerical_features] = numerical_imputer.fit_transform(X_train[numerical_features])
    X_test[numerical_features] = numerical_imputer.transform(X_test[numerical_features])

    # Impute missing values for categorical features
    categorical_imputer = SimpleImputer(strategy='most_frequent')
    categorical_features = X_train.select_dtypes(include=['object']).columns
    X_train[categorical_features] = categorical_imputer.fit_transform(X_train[categorical_features])
    X_test[categorical_features] = categorical_imputer.transform(X_test[categorical_features])

    return X_train, X_test

# Impute missing values
X_train, X_test = impute_missing_values(X_train, X_test)

# Displaying imputed data
print("X_train after imputation:")
print(X_train)
print("\nX_test after imputation:")
print(X_test)
print("\ny_train:")
print(y_train)
print("\ny_test:")
print(y_test)

print(type(X_train), type(X_test), type(y_train), type(y_test))
# Out:
# X_train after imputation:
#          region         province     district       type    subtype  \
# 50397  Flanders    East Flanders  Dendermonde      HOUSE      HOUSE
# 26027  Flanders  Flemish Brabant       Leuven      HOUSE      HOUSE
# 26855  Flanders          Limburg      Hasselt      HOUSE      HOUSE
# 6618   Wallonie          Hainaut         Mons      HOUSE      VILLA
# 7648   Flanders    East Flanders        Aalst      HOUSE      HOUSE
# ...         ...              ...          ...        ...        ...
# 56822  Flanders    East Flanders        Aalst      HOUSE      HOUSE
# 36910  Flanders    East Flanders        Aalst  APARTMENT       LOFT
# 5914   Wallonie            Namur       Dinant      HOUSE      HOUSE
# 13873  Flanders          Antwerp      Antwerp  APARTMENT  APARTMENT
# 37487  Flanders    West Flanders        Tielt  APARTMENT  APARTMENT
#
#       heatingType epcScores  bedrooms     surface  surfaceGood  \
# 50397         GAS         C       3.0  150.000000   436.000000
# 26027    ELECTRIC         F       4.0  237.000000  3382.000000
# 26855         GAS         B       4.0  211.000000    79.000000
# 6618          GAS         C       4.0  323.000000  1507.000000
# 7648       PELLET         F       3.0  189.000000   220.000000
# ...           ...       ...       ...         ...          ...
# 56822         GAS         D       2.0  136.000000   485.000000
# 36910         GAS         B       0.0  311.000000   736.043757
# 5914      FUELOIL         G       3.0  152.646507   619.000000
# 13873         GAS         B       3.0   80.000000   736.043757
# 37487    ELECTRIC         B       2.0   95.000000   736.043757
#
#             condition  facadeCount hasKitchenSetup  isFurnished  \
# 50397  JUST_RENOVATED     3.000000       INSTALLED          0.0
# 26027            GOOD     4.000000       INSTALLED          0.0
# 26855     TO_RENOVATE     2.000000   SEMI_EQUIPPED          0.0
# 6618           AS_NEW     4.000000       INSTALLED          0.0
# 7648    TO_BE_DONE_UP     3.000000       INSTALLED          0.0
# ...               ...          ...             ...          ...
# 56822            GOOD     3.000000  HYPER_EQUIPPED          0.0
# 36910            GOOD     2.777264       INSTALLED          0.0
# 5914      TO_RENOVATE     4.000000       INSTALLED          0.0
# 13873            GOOD     4.000000   SEMI_EQUIPPED          0.0
# 37487          AS_NEW     2.777264       INSTALLED          0.0
#
#        fireplaceExists  hasSwimmingPool            floodZone
# 50397              0.0              0.0       NON_FLOOD_ZONE
# 26027              0.0              0.0       NON_FLOOD_ZONE
# 26855              0.0              0.0       NON_FLOOD_ZONE
# 6618               0.0              0.0       NON_FLOOD_ZONE
# 7648               0.0              0.0  POSSIBLE_FLOOD_ZONE
# ...                ...              ...                  ...
# 56822              0.0              0.0       NON_FLOOD_ZONE
# 36910              0.0              0.0       NON_FLOOD_ZONE
# 5914               0.0              0.0       NON_FLOOD_ZONE
# 13873              1.0              0.0       NON_FLOOD_ZONE
# 37487              0.0              0.0       NON_FLOOD_ZONE
#
# [43841 rows x 17 columns]
#
# X_test after imputation:
#          region         province         district       type       subtype  \
# 16962  Flanders  Flemish Brabant           Leuven      HOUSE         HOUSE
# 9746   Flanders  Flemish Brabant  Halle-Vilvoorde      HOUSE         HOUSE
# 15135  Flanders          Antwerp         Turnhout  APARTMENT        DUPLEX
# 14248  Flanders    East Flanders            Aalst  APARTMENT        DUPLEX
# 5425   Flanders    West Flanders        Roeselare      HOUSE         HOUSE
# ...         ...              ...              ...        ...           ...
# 9951   Wallonie            Liège         Verviers      HOUSE         HOUSE
# 59118  Flanders    East Flanders       Oudenaarde  APARTMENT  SERVICE_FLAT
# 38824  Wallonie            Liège            Liège      HOUSE         HOUSE
# 41018  Flanders          Antwerp         Turnhout  APARTMENT     APARTMENT
# 11325  Flanders  Flemish Brabant           Leuven  APARTMENT     APARTMENT
#
#       heatingType epcScores  bedrooms     surface  surfaceGood      condition  \
# 16962     FUELOIL         F       4.0  277.000000   361.000000  TO_BE_DONE_UP
# 9746     ELECTRIC         F       3.0  151.000000  2872.000000           GOOD
# 15135         GAS         B       3.0  173.000000   736.043757           GOOD
# 14248         GAS         B       3.0  140.000000   736.043757           GOOD
# 5425          GAS         B       4.0  187.000000   280.000000           GOOD
# ...           ...       ...       ...         ...          ...            ...
# 9951      FUELOIL         G       3.0  152.646507   684.000000    TO_RENOVATE
# 59118         GAS         B       1.0   66.000000   736.043757         AS_NEW
# 38824     FUELOIL         C       4.0  160.000000   438.000000           GOOD
# 41018         GAS         B       3.0  101.000000   736.043757           GOOD
# 11325         GAS         B       2.0   67.000000   736.043757           GOOD
#
#        facadeCount hasKitchenSetup  isFurnished  fireplaceExists  \
# 16962     4.000000       INSTALLED          0.0              0.0
# 9746      3.000000       INSTALLED          0.0              0.0
# 15135     2.777264       INSTALLED          0.0              0.0
# 14248     3.000000       INSTALLED          0.0              0.0
# 5425      2.777264       INSTALLED          0.0              0.0
# ...            ...             ...          ...              ...
# 9951      3.000000       INSTALLED          0.0              0.0
# 59118     4.000000       INSTALLED          0.0              0.0
# 38824     2.777264       INSTALLED          0.0              1.0
# 41018     2.000000       INSTALLED          0.0              0.0
# 11325     2.777264       INSTALLED          0.0              0.0
#
#        hasSwimmingPool       floodZone
# 16962              0.0  NON_FLOOD_ZONE
# 9746               0.0  NON_FLOOD_ZONE
# 15135              0.0  NON_FLOOD_ZONE
# 14248              0.0  NON_FLOOD_ZONE
# 5425               0.0  NON_FLOOD_ZONE
# ...                ...             ...
# 9951               0.0  NON_FLOOD_ZONE
# 59118              0.0  NON_FLOOD_ZONE
# 38824              0.0  NON_FLOOD_ZONE
# 41018              0.0  NON_FLOOD_ZONE
# 11325              0.0  NON_FLOOD_ZONE
#
# [10961 rows x 17 columns]
#
# y_train:
# 50397    435000.0
# 26027    449000.0
# 26855    160000.0
# 6618     295000.0
# 7648     269000.0
#            ...
# 56822    315000.0
# 36910    749000.0
# 5914     145000.0
# 13873    219000.0
# 37487    286290.0
# Name: price_main, Length: 43841, dtype: float64
#
# y_test:
# 16962    269000.0
# 9746     345000.0
# 15135    299000.0
# 14248    225000.0
# 5425     377000.0
#            ...
# 9951     295000.0
# 59118    269000.0
# 38824    289000.0
# 41018    338000.0
# 11325    235000.0
# Name: price_main, Length: 10961, dtype: float64
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.series.Series'> <class 'pandas.core.series.Series'>

# %%
print(y_train.shape)
# Out:
# (43841,)

# %%
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Iterate over each column in X_train
for col in X_train.columns:    
    X_train[col]= label_encoder.fit_transform(X_train[col])

    # Transform X_test[col], handle unknown labels by replacing them with a constant (e.g., -1)
    X_test[col] = X_test[col].map(lambda s: label_encoder.transform([s])[0] if s in label_encoder.classes_ else -1)

print("X_train encoded:")
print(X_train)
# Out:
# X_train encoded:
#        region  province  district  type  subtype  heatingType  epcScores  \
# 50397       1         2         8     1       10            3          4
# 26027       1         3        18     1       10            1          6
# 26855       1         5        14     1       10            3          3
# 6618        2         4        23     1       21            3          4
# 7648        1         2         0     1       10            4          6
# ...       ...       ...       ...   ...      ...          ...        ...
# 56822       1         2         0     1       10            3          5
# 36910       1         2         0     0       12            3          3
# 5914        2         8        10     1       10            2          7
# 13873       1         0         1     0        0            3          3
# 37487       1        10        35     0        0            1          3
#
#        bedrooms  surface  surfaceGood  condition  facadeCount  \
# 50397         3      139          427          2            3
# 26027         4      227         2324          1            4
# 26855         4      201           70          4            1
# 6618          4      313         1470          0            4
# 7648          3      179          211          3            3
# ...         ...      ...          ...        ...          ...
# 56822         2      125          476          1            3
# 36910         0      301          728          1            2
# 5914          3      142          610          4            4
# 13873         3       69          728          1            4
# 37487         2       84          728          0            2
#
#        hasKitchenSetup  isFurnished  fireplaceExists  hasSwimmingPool  \
# 50397                1            0                0                0
# 26027                1            0                0                0
# 26855                3            0                0                0
# 6618                 1            0                0                0
# 7648                 1            0                0                0
# ...                ...          ...              ...              ...
# 56822                0            0                0                0
# 36910                1            0                0                0
# 5914                 1            0                0                0
# 13873                3            0                1                0
# 37487                1            0                0                0
#
#        floodZone
# 50397          2
# 26027          2
# 26855          2
# 6618           2
# 7648           3
# ...          ...
# 56822          2
# 36910          2
# 5914           2
# 13873          2
# 37487          2
#
# [43841 rows x 17 columns]

# %%
# Assuming you have a list of column names (feature names) for X_train and X_test
column_names = X_train.columns.tolist()

# Initialize StandardScaler
scaler = StandardScaler()

# Fit the scaler to the training data and transform both training and test sets
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Convert the scaled arrays back into DataFrames
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=column_names)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=column_names)

# %%
# Initialize Linear Regression model
regressor = LinearRegression()

# Fit the model to the scaled training data
regressor.fit(X_train, y_train)

# Evaluate the model on the scaled test data
score = regressor.score(X_test, y_test)

print("R^2 Score:", score)
# Out:
# R^2 Score: 0.4632083262742467

# %%
# Get the coefficients
coefficients = regressor.coef_
X_train.head()

# Print the coefficients along with corresponding feature names if available
if hasattr(X_train, 'columns'):
    print("Feature Coefficients:")
    for feature, coef in zip(X_train.columns, coefficients):
        print(feature, ':', coef)
else:
    print("Feature Coefficients:", coefficients)
# Out:
# Feature Coefficients:
# region : -79788.482597899
# province : -170.12262109881556
# district : -737.4965206913998
# type : 19272.94532001431
# subtype : 1701.7287690175704
# heatingType : 2000.6842449363924
# epcScores : -18372.87380626524
# bedrooms : 22449.77508459753
# surface : 615.4960358060321
# surfaceGood : 55.2530186530945
# condition : -23396.70319796947
# facadeCount : 9339.386899817591
# hasKitchenSetup : -1580.654976070529
# isFurnished : -5147.929165222759
# fireplaceExists : 13304.31192934324
# hasSwimmingPool : 69701.50232841517
# floodZone : -5945.012974656768
